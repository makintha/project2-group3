# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as sts
import numpy as np

parks = pd.read_csv("Resources/state-park-facility-points-1.csv")
attendance = pd.read_csv("Resources/State_Park_Annual_Attendance_Figures_by_Facility___Beginning_2003.csv")
income = pd.read_csv("Resources/Median Household Income by County.csv")
population = pd.read_csv("Resources/Population Estimates by County.csv")

# %%
parks = parks.drop(columns=['Facility URL', 'Golf URL', 'Nature Center URL', 'Location']).fillna('N')

# %%
parks = parks.sort_values(by='Name')
parks
parks.to_csv (r'CleanedData/StatePark.csv', index = False, header=True)

# %%
att2019 = attendance[attendance["Year"] == 2019]
att2019.rename(columns={'Facility': 'Name'}, inplace=True)
att2019 = att2019.sort_values(by = 'Name')
grouped_att = att2019.groupby(['County'])['Attendance'].sum()
grouped_county = att2019.groupby(['County'])['County']

park_att = pd.DataFrame({'County': grouped_county , 'Attendance': grouped_att})

# park_att['County']= park_att.index
# park_att.reset_index(drop=True, inplace=True)
df['text_new'] = df['text'].str.split('::').str[0]
# Out:
# C:\Users\bluec\anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# C:\Users\bluec\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1229: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   v = np.array(v, copy=False)
# C:\Users\bluec\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1623: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   subarr = np.array(values, dtype=dtype, copy=copy)
# C:\Users\bluec\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-abee239ccee6> in <module>
#       9 # park_att['County']= park_att.index
#      10 # park_att.reset_index(drop=True, inplace=True)
# ---> 11 df['text_new'] = df['text'].str.split('::').str[0]
#
# NameError: name 'df' is not defined

# %%
income['Median Household Income by County'] = income['Median Household Income by County'].str.replace('County', '')
income.drop(income.tail(1).index,inplace=True)
income.drop(income.head(1).index,inplace=True)
income.rename(columns={'Median Household Income by County':'County', 'Unnamed: 1': 'Income', 'Unnamed: 2': 'Margin of Error'}, inplace=True)
income.to_csv (r'CleanedData/income.csv', index = False, header=True)

# %%
population['Population Estimates by County'] = population['Population Estimates by County'].str.replace('County', '')
population.drop(income.tail(1).index,inplace=True)
population.drop(income.head(1).index,inplace=True)
population.rename(columns={'Population Estimates by County':'County', 'Unnamed: 1': 'Population'}, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Population Estimates by County'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-5b1bbe681a63> in <module>
# ----> 1 population['Population Estimates by County'] = population['Population Estimates by County'].str.replace('County', '')
#       2 population.drop(income.tail(1).index,inplace=True)
#       3 population.drop(income.head(1).index,inplace=True)
#       4 population.rename(columns={'Population Estimates by County':'County', 'Unnamed: 1': 'Population'}, inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'Population Estimates by County'

# %%
population.to_csv (r'CleanedData/population.csv', index = False, header=True)

# %%
att2019.to_csv (r'CleanedData/2019_Attendance.csv', index = False, header=True)
park_att.to_csv (r'CleanedData/park_county_attendance.csv', index = False, header=True)

# %%
import sqlite3 as sql
cleaned_data = pd.read_csv("CleanedData/county_attendance_income_pop.csv")
conn = sql.connect('newyork.db')

cleaned_data['Income'] = cleaned_data['Income'].str.replace('$', '')
cleaned_data['Income'] = cleaned_data['Income'].str.replace(',', '')
cleaned_data['Population'] = cleaned_data['Population'].str.replace(',', '')
cleaned_data = cleaned_data.drop(columns=['Margin of Error'])

cleaned_data
cleaned_data.to_sql('county_data', conn, if_exists='replace', index= False)
cleaned_data.to_csv('county_data', conn, if_exists='replace', index= False)
explore = pd.read_sql("SELECT * FROM county_data", conn)
explore
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-b49df7960ad6> in <module>
#       3 conn = sql.connect('newyork.db')
#       4
# ----> 5 cleaned_data['Income'] = cleaned_data['Income'].str.replace('$', '')
#       6 cleaned_data['Income'] = cleaned_data['Income'].str.replace(',', '')
#       7 cleaned_data['Population'] = cleaned_data['Population'].str.replace(',', '')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5133             or name in self._accessors
#    5134         ):
# -> 5135             return object.__getattribute__(self, name)
#    5136         else:
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
#     188         # Replace the property with the accessor object. Inspired by:
#     189         # https://www.pydanny.com/cached-property.html
#
# ~\anaconda3\lib\site-packages\pandas\core\strings.py in __init__(self, data)
#    2098
#    2099     def __init__(self, data):
# -> 2100         self._inferred_dtype = self._validate(data)
#    2101         self._is_categorical = is_categorical_dtype(data.dtype)
#    2102         self._is_string = data.dtype.name == "string"
#
# ~\anaconda3\lib\site-packages\pandas\core\strings.py in _validate(data)
#    2155
#    2156         if inferred_dtype not in allowed_types:
# -> 2157             raise AttributeError("Can only use .str accessor with string values!")
#    2158         return inferred_dtype
#    2159
#
# AttributeError: Can only use .str accessor with string values!

# %%
yearly_attendance = pd.read_csv("Resources/State_Park_Annual_Attendance_Figures_by_Facility___Beginning_2003.csv")
yearly_attendance['Facility'] = yearly_attendance['Facility'].str.replace(' ', '_')
yearly_attendance['Facility'] = yearly_attendance['Facility'].str.replace('St_Pk', '')
yearly_attendance['Facility'] = yearly_attendance['Facility'].str.replace('Park', '')
yearly_attendance['Facility'] = yearly_attendance['Facility'].str.replace('_', ' ')

yearly_attendance.head(20)
# Out:
#     Year  OPRHP Region       County              Facility  Attendance
# 0   2020  Finger Lakes     Tompkins   Allan Treman Marina      341963
# 1   2019  Finger Lakes     Tompkins   Allan Treman Marina      355313
# 2   2018  Finger Lakes     Tompkins   Allan Treman Marina      291507
# 3   2017  Finger Lakes     Tompkins   Allan Treman Marina      311260
# 4   2016  Finger Lakes     Tompkins   Allan Treman Marina      318309
# 5   2015  Finger Lakes     Tompkins   Allan Treman Marina      266112
# 6   2014  Finger Lakes     Tompkins   Allan Treman Marina      210543
# 7   2013  Finger Lakes     Tompkins   Allan Treman Marina      292200
# 8   2012  Finger Lakes     Tompkins   Allan Treman Marina      162986
# 9   2011  Finger Lakes     Tompkins   Allan Treman Marina      172579
# 10  2010  Finger Lakes     Tompkins   Allan Treman Marina      205460
# 11  2009  Finger Lakes     Tompkins   Allan Treman Marina      184372
# 12  2008  Finger Lakes     Tompkins   Allan Treman Marina      160923
# 13  2007  Finger Lakes     Tompkins   Allan Treman Marina      153700
# 14  2006  Finger Lakes     Tompkins   Allan Treman Marina      176102
# 15  2005  Finger Lakes     Tompkins   Allan Treman Marina      162478
# 16  2004  Finger Lakes     Tompkins   Allan Treman Marina      132838
# 17  2003  Finger Lakes     Tompkins   Allan Treman Marina      145622
# 18  2020      Allegany  Cattaraugus  Allegany Quaker Area      703521
# 19  2019      Allegany  Cattaraugus  Allegany Quaker Area      802727

# %%
yearly_attendance['LastAttendance'] = yearly_attendance['Attendance']


yearly_attendance['LastAttendance'][0::18] = 0
yearly_attendance['LastAttendance'] = yearly_attendance['LastAttendance'].shift(-1)
yearly_attendance = yearly_attendance.drop(columns=['OPRHP Region', 'County']).fillna('0')
yearly_attendance.to_csv (r'CleanedData/yearly_attendance.csv', index = False, header=True)
yearly_attendance.head(50)
# Out:
# <ipython-input-20-c1f943383780>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yearly