# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as sts
import numpy as np

parks = pd.read_csv("Resources/state-park-facility-points-1.csv")
attendance = pd.read_csv("Resources/State_Park_Annual_Attendance_Figures_by_Facility___Beginning_2003.csv")

# %%
parks = parks.drop(columns=['Facility URL', 'Golf URL', 'Nature Center URL', 'Location']).fillna('N')

# %%
parks = parks.sort_values(by='Name')
parks
# Out:
#                               Name         Category  Region        County  \
# 144  Alfred E. Smith/Sunken Meadow       State Park       9       Suffolk
# 36                 Allan H. Treman  Marine Facility       4      Tompkins
# 21                        Allegany       State Park       2   Cattaraugus
# 0                          Amherst       State Park       1          Erie
# 145                Amsterdam Beach       State Park       9       Suffolk
# ..                             ...              ...     ...           ...
# 176                       Wildwood       State Park       9       Suffolk
# 212        Wilson Hill Boat Launch  Marine Facility      10  St. Lawrence
# 19                Wilson-Tuscarora       State Park       1       Niagara
# 117                    Wonder Lake       State Park       7        Putnam
# 20                  Woodlawn Beach       State Park       1          Erie
#
#     Golf Camp Playground Nature Center Beach  Longitude   Latitude
# 144    Y    N          Y             N     Y -73.263206  40.909992
# 36     N    N          N             N     N -76.517568  42.461397
# 21     N    Y          Y           Y-A   Y-M -78.768559  42.054758
# 0      N    N          N             N     N -78.748088  42.971001
# 145    N    N          N             N     N -71.900265  41.047771
# ..   ...  ...        ...           ...   ...        ...        ...
# 176    N    Y          Y             N     Y -72.794573  40.960500
# 212    N    N          N             N     N -75.007000  44.929029
# 19     N    N          Y             N     Y -78.855609  43.303777
# 117    N    N          N             N     N -73.646586  41.491903
# 20     N    N          Y             N     Y -78.852208  42.793819
#
# [249 rows x 11 columns]

# %%
parks.to_csv (r'CleanedData/StatePark.csv', index = False, header=True)

# %%
att2019 = attendance[attendance["Year"] == 2019]

# %%
att2019.rename(columns={'Facility': 'Name'}, inplace=True)
att2019 = att2019.sort_values(by = 'Name')
att2019
# Out:
# C:\Users\bluec\anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#       Year      OPRHP Region           County                     Name  \
# 1     2019      Finger Lakes         Tompkins      Allan Treman Marina
# 19    2019          Allegany      Cattaraugus     Allegany Quaker Area
# 37    2019          Allegany      Cattaraugus  Allegany Red House Area
# 55    2019       Long Island          Suffolk          Amsterdam Beach
# 59    2019         Palisades  Orange/Rockland            Anthony Wayne
# ...    ...               ...              ...                      ...
# 4164  2019           Niagara          Niagara                Whirlpool
# 4182  2019       Long Island          Suffolk      Wildwood State Park
# 4200  2019  Thousand Islands      St Lawrence  Wilson Hill Boat Launch
# 4218  2019           Niagara          Niagara   Wilson Tuscarora St Pk
# 4236  2019           Niagara             Erie                 Woodlawn
#
#       Attendance
# 1         355313
# 19        802727
# 37        718483
# 55         13860
# 59         83463
# ...          ...
# 4164      417994
# 4182      447597
# 4200        8406
# 4218      218596
# 4236           0
#
# [244 rows x 5 columns]

# %%
att2019.to_csv (r'C2019_Attendance.csv', index = False, header=True)

# %%
joined = pd.merge(parks, att2019, on ='Name')
joined = joined.sort_values(by = 'Name')
joined
# Out:
#                        Name             Category  Region      County_x Golf  \
# 0           Amsterdam Beach           State Park       9       Suffolk    N
# 1             Beaver Island           State Park       1          Erie    Y
# 2                 Beechwood           State Park       4         Wayne    N
# 3    Bennington Battlefield  State Historic Site      11    Rensselaer    N
# 4                  Blauvelt           State Park       8      Rockland    N
# ..                      ...                  ...     ...           ...  ...
# 67  Stony Point Battlefield  State Historic Site       8      Rockland    N
# 68               Storm King           State Park       8        Orange    N
# 69           Whetstone Gulf           State Park      10         Lewis    N
# 70                Whirlpool           State Park       1       Niagara    N
# 71  Wilson Hill Boat Launch      Marine Facility      10  St. Lawrence    N
#
#    Camp Playground Nature Center Beach  Longitude   Latitude  Year  \
# 0     N          N             N     N -71.900265  41.047771  2019
# 1     N          Y             Y     Y -78.953106  42.965766  2019
# 2     N          N             N     N -77.033793  43.266694  2019
# 3     N          N             N     N -73.302251  42.939506  2019
# 4     N          N             N     N -73.937373  41.074241  2019
# ..  ...        ...           ...   ...        ...        ...   ...
# 67    N          N             N     N -73.976373  41.241090  2019
# 68    N          N             N     N -73.991346  41.425644  2019
# 69    N          Y             N     Y -75.477415  43.698508  2019
# 70    N          Y             N     N -79.063418  43.120400  2019
# 71    N          N             N     N -75.007000  44.929029  2019
#
#         OPRHP Region     County_y  Attendance
# 0        Long Island      Suffolk       13860
# 1            Niagara         Erie      306395
# 2       Finger Lakes        Wayne           0
# 3   Saratoga/Capital   Rensselaer       29859
# 4          Palisades     Rockland       31420
# ..               ...          ...         ...
# 67         Palisades     Rockland       35533
# 68         Palisades       Orange       14239
# 69  Thousand Islands        Lewis       42067
# 70           Niagara      Niagara      417994
# 71  Thousand Islands  St Lawrence        8406
#
# [72 rows x 15 columns]
