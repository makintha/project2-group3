# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as sts
import numpy as np

parks = pd.read_csv("Resources/state-park-facility-points-1.csv")
attendance = pd.read_csv("Resources/State_Park_Annual_Attendance_Figures_by_Facility___Beginning_2003.csv")

# %%
parks = parks.drop(columns=['Facility URL', 'Golf URL', 'Nature Center URL', 'Location']).fillna('N')

# %%
parks = parks.sort_values(by='Name')

# %%
parks
parks.to_csv (r'CleanedData/StatePark.csv', index = False, header=True)

# %%
att2019 = attendance[attendance["Year"] == 2019]

# %%
att2019.rename(columns={'Facility': 'Name'}, inplace=True)
att2019 = att2019.sort_values(by = )
# Out:
# C:\Users\bluec\anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
att2019.to_csv (r'C2019_Attendance.csv', index = False, header=True)

# %%
joined = pd.merge(parks, att2019, on ='Name')
joined
# Out:
#                   Name             Category  Region    County_x Golf Camp  \
# 0        Beaver Island           State Park       1        Erie    Y    N
# 1            Whirlpool           State Park       1     Niagara    N    N
# 2         Braddock Bay           State Park       3      Monroe    N    N
# 3          Silver Lake           State Park       3     Wyoming    N    N
# 4            Beechwood           State Park       4       Wayne    N    N
# ..                 ...                  ...     ...         ...  ...  ...
# 67  Schoharie Crossing  State Historic Site      11  Montgomery    N    N
# 68    Schuyler Mansion  State Historic Site      11      Albany    N    N
# 69      Clay Pit Ponds  State Park Preserve      12    Richmond    N    N
# 70        Gantry Plaza           State Park      12      Queens    N    N
# 71    Roberto Clemente           State Park      12       Bronx    N    N
#
#    Playground Nature Center Beach  Longitude   Latitude  Year  \
# 0           Y             Y     Y -78.953106  42.965766  2019
# 1           Y             N     N -79.063418  43.120400  2019
# 2           N             N     N -77.703866  43.294195  2019
# 3           N             N     N -78.056561  42.679254  2019
# 4           N             N     N -77.033793  43.266694  2019
# ..        ...           ...   ...        ...        ...   ...
# 67          Y             N     N -74.267570  42.949345  2019
# 68          N             N     N -73.759287  42.641323  2019
# 69          N           Y-A     N -74.229046  40.540564  2019
# 70          Y             N     N -73.959045  40.744352  2019
# 71          Y             N     N -73.920043  40.855364  2019
#
#         OPRHP Region    County_y  Attendance
# 0            Niagara        Erie      306395
# 1            Niagara     Niagara      417994
# 2            Genesee      Monroe       37552
# 3            Genesee     Wyoming       27031
# 4       Finger Lakes       Wayne           0
# ..               ...         ...         ...
# 67  Saratoga/Capital  Montgomery       89021
# 68  Saratoga/Capital      Albany       15206
# 69     New York City    Richmond       47060
# 70     New York City      Queens     1898951
# 71     New York City       Bronx      339868
#
# [72 rows x 15 columns]
